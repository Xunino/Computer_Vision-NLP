# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/BT_ML
# Out:
# /content/drive/My Drive/BT_ML

# %%
# Word Embeddings: Mô hình hóa các từ thành vector, sau đó lấy các feature tương đồng giữa các từ
# Word Embeddings - là một model được training sẵn để lấy các feature của các từ

# %%
# - Đầu vào của Embedding là một convert của một từ điển
# - Đầu ra là một không gian nhiều chiều và mỗi từ sẽ là một vector ở trong đó - số chiều do chúng ta định nghĩa
# - Các từ giống nhau thường được sử dụng trong ngữ cảnh giống nhau

# %%
# Sử dụng data để train Word2vec
# Cách 1: Skip-gram
#       - Lấy 1 từ đầu vào và dự đoán các từ xung quanh nó
# Cách 2: CBOW
#       - Lấy những từ xung quanh để dự đoán từ ở giữa

# ==>>> Để làm được những điều như trên ta cần đưa các từ thành dạng One-hot-Vector
